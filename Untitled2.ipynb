# %% [markdown]
# <a href="https://colab.research.google.com/github/Afitr06/uts_Afit/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/drive/MyDrive/Colab Notebooks/afit.jfif", cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1599 at 0x7F5FB07CD250>

# %%
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/afit.jfif', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1200x1599 at 0x7F5F9B3DB990>

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (1599, 1200)
# 1918800
# uint8

# %%
import numpy as np
a = np.array([[1,2,2,2,10],[10,20,30,40,50]])
print (a)
print (a.ravel())
print (a.flatten())
plt.hist(a.ravel (),bins = 50, range = [0,50])
plt.show()
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %%
plt.hist(img.ravel (), bins = 256, range = [0,256])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
color = ('b', 'g', 'r')
for i,col in enumerate(color) :
  histogr = cv2.calcHist ( [img], [i], None, [256], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,256])
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-aa097c2657db> in <module>
#       1 color = ('b', 'g', 'r')
#       2 for i,col in enumerate(color) :
# ----> 3   histogr = cv2.calcHist ( [img], [i], None, [256], [0,256])
#       4   plt.plot(histogr, color = col)
#       5   plt.xlim([0,256])
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/histogram.cpp:160: error: (-215:Assertion failed) j < nimages in function 'histPrepareImages'

# %%
color =('b','g','r' = cv2.split(img)
cv2_imshow(img)
# Out:
#   File "<ipython-input-41-ad5d55155b06>", line 1
#     color =('b','g','r' = cv2.split(img)
#                         ^
# SyntaxError: invalid syntax

# %%
plt.hist(bluech.ravel(),bins = 16, [0, 256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.()
# Out:
#   File "<ipython-input-45-5264c24b92e8>", line 4
#     plt.()
#         ^
# SyntaxError: invalid syntax
